# %%
# %pip install yarngpt
# Out:
# ...
#   Using cached scipy-1.15.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# ...
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached encodec-0.1.1.tar.gz (3.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached matplotlib-3.10.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# ...
#   Using cached jsonargparse-4.37.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached torchcrepe-0.0.23-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# ...
#   Using cached pesq-0.0.4.tar.gz (38 kB)
#   Installing build dependencies ... done
# ...

# %%
from yarngpt import generate_speech
import torchaudio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from yarngpt import generate_speech
#       2 import torchaudio
#
# ModuleNotFoundError: No module named 'yarngpt'
